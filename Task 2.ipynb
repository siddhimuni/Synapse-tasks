# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Synapse tasks/HPSpells.csv")

# %%
data
# Out:
#                                 Name         Incantation             Type  \
# 0                     Bedazzling Hex             Unknown              Hex
# 1                        Ventus Jinx              Ventus             Jinx
# 2                             Portus              Portus            Charm
# 3                          Badgering             Unknown  Transfiguration
# 4                          Trip Jinx             Unknown             Jinx
# 5                           Langlock            Langlock             Jinx
# 6                        Crinus Muto         Crinus Muto  Transfiguration
# 7                           Age Line             Unknown            Charm
# 8                   Jelly-Brain Jinx             Unknown             Jinx
# 9            Entrail-Expelling Curse             Unknown            Curse
# 10                        Vera Verto          Vera Verto  Transfiguration
# 11                    Lapifors Spell            Lapifors  Transfiguration
# ...

# %%
data.head()
# Out:
#              Name Incantation             Type  \
# 0  Bedazzling Hex     Unknown              Hex
# 1     Ventus Jinx      Ventus             Jinx
# 2          Portus      Portus            Charm
# 3       Badgering     Unknown  Transfiguration
# 4       Trip Jinx     Unknown             Jinx
#
#                              Effect Light
# 0                  Disguises things   NaN
# 1            Jet of spiralling wind  Grey
# 2         Turns object into Portkey  Blue
# 3  Turns target human into a badger   NaN
# 4                      Trips victim   NaN

# %%
new_data = data[data['Type']!='Hex']
new_data
# Out:
#                                 Name         Incantation             Type  \
# 1                        Ventus Jinx              Ventus             Jinx
# 2                             Portus              Portus            Charm
# 3                          Badgering             Unknown  Transfiguration
# 4                          Trip Jinx             Unknown             Jinx
# 5                           Langlock            Langlock             Jinx
# 6                        Crinus Muto         Crinus Muto  Transfiguration
# 7                           Age Line             Unknown            Charm
# 8                   Jelly-Brain Jinx             Unknown             Jinx
# 9            Entrail-Expelling Curse             Unknown            Curse
# 10                        Vera Verto          Vera Verto  Transfiguration
# 11                    Lapifors Spell            Lapifors  Transfiguration
# 12                         Fumos Duo           Fumos Duo            Charm
# ...

# %%
data_2=new_data.dropna(subset=['Light'])

# %%
data_2
# Out:
#                        Name         Incantation             Type  \
# 1               Ventus Jinx              Ventus             Jinx
# 2                    Portus              Portus            Charm
# 5                  Langlock            Langlock             Jinx
# 6               Crinus Muto         Crinus Muto  Transfiguration
# 7                  Age Line             Unknown            Charm
# 10               Vera Verto          Vera Verto  Transfiguration
# 11           Lapifors Spell            Lapifors  Transfiguration
# 12                Fumos Duo           Fumos Duo            Charm
# 15       Lacarnum Inflamari  Lacarnum Inflamari            Charm
# 16             Sectumsempra        Sectumsempra            Curse
# 21                 Evanesce            Evanesce  Transfiguration
# 24          Hair Loss Curse            Calvorio            Curse
# 27           Sonorous Charm             Unknown            Charm
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
x_charm = new_data.loc[(new_data['Type']=='Charm')]
x_charm.shape
# Out:
# (15, 5)

# %%
x_jinx = new_data.loc[(new_data['Type']=='Jinx')]
x_jinx.shape
# Out:
# (10, 5)

# %%
x_trans = new_data.loc[(new_data['Type']=='Transfiguration')]
x_trans.shape
# Out:
# (12, 5)

# %%
x_curse = new_data.loc[(new_data['Type']=='Curse')]
x_curse.shape
# Out:
# (8, 5)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = {'x_charm':x_charm.shape[0],
       'x_jinx':x_jinx.shape[0],
       'x_trans':x_trans.shape[0],
       'x_curse':x_curse.shape[0]
       }
x = list(data.keys())
y = list(data.values())

fig = plt.figure(figsize =(10,5))
plt.bar(  x ,y,width = 0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
x = [['Charm','Jinx','Transfiguration','Curse']]
y = [[x_charm.shape[0],x_jinx.shape[0],x_trans.shape[0],x_curse.shape[0]]]

plt.bar(x,y,width = 1)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2373, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2372 try:
# -> 2373     left = x - width / 2
#    2374 except TypeError as e:
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U15'), dtype('float64')) -> None
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 4>()
#       1 x = [['Charm','Jinx','Transfiguration','Curse']]
#       2 y = [[x_charm.shape[0],x_jinx.shape[0],x_trans.shape[0],x_curse.shape[0]]]
# ----> 4 plt.bar(x,y,width = 1)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2387, in bar(x, height, width, bottom, align, data, **kwargs)
# ...
